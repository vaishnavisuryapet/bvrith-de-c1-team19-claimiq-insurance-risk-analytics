# %% [markdown]
# # 06 — Power BI Export
#
# **Week:** 8
#
# Goal: Export Gold outputs for Power BI Desktop.

# %%
# Option 1: save Gold table as CSV files in a volume or accessible location.
gold_df = spark.table("gold_event_summary_by_date")

export_path = "/Volumes/workspace/default/<project_name>/gold_exports/gold_event_summary_by_date"
gold_df.coalesce(1).write.mode("overwrite").option("header", True).csv(export_path)

print("Gold export path:", export_path)

# %% [markdown]
# ## Power BI Rule
#
# Power BI must use Gold outputs only. Do not connect Power BI directly to raw CSV files.

# %% [markdown]
# ## Evidence to Capture
#
# - Screenshot of Gold export
# - Screenshot of Power BI connected to Gold output
# - Save PBIX in `dashboard/`
